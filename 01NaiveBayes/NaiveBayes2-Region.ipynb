# %% [markdown]
# # 朴素贝叶斯分类器应用2——从个人广告中获取区域倾向
#
# 1. 收集数据：从RSS源收集内容，这里需要对RSS源构建一个接口
# 2. 处理数据：将文本文件解析成词条向量
# 3. 分析数据：检查词条确保解析的正确性
# 4. 训练算法：使用trainBayes函数
# 5. 测试算法：观察错误率，确保分类器可用。可以修改切分程序，降低错误率，提高分类结果
# 6. 使用算法：构建一个完整的程序，封装所有内容。给定两个RSS源，显示最常用的公共词

# %%
import feedparser
ny = feedparser.parse('https://pennstate.craigslist.org/search/sss?query=table%20saw&sort=rel')

# %%
ny
# Out:
# {'bozo': 1,
#  'entries': [],
#  'feed': {'html': {'class': 'no-js'},
#   'meta': {'name': 'viewport',
#    'content': 'width=device-width,initial-scale=1'},
#   'links': [{'rel': 'canonical',
#     'href': 'https://pennstate.craigslist.org/search/sss',
#     'type': 'text/html'},
#    {'rel': 'alternate',
#     'type': 'application/rss+xml',
#     'href': 'https://pennstate.craigslist.org/search/sss?format=rss&query=table%20saw&sort=rel',
#     'title': 'RSS feed for craigslist | state college for sale &quot;table saw&quot; - craigslist'},
#    {'type': 'text/css',
#     'rel': 'stylesheet',
#     'media': 'all',
#     'href': 'https://www.craigslist.org/styles/cl.css?v=f45c4074e9853c0ceb280398a8131359'},
#    {'type': 'text/css',
#     'rel': 'stylesheet',
#     'media': 'all',
#     'href': 'https://www.craigslist.org/styles/search.css?v=bc035cbbc3978b0ec9df93944cdf349b'},
#    {'type': 'text/css',
#     'rel': 'stylesheet',
#     'media': 'all',
# ...
